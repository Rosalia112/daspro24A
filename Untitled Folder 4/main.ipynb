# %%
import pandas as pd

df = pd.read_csv('hsr_character-data.csv')
df
# Out:
#         character  rarity          path combat_type  wb_b-atk  wb_skill  \
# 0       march_7th       4  preservation         ice        30         0
# 1        dan_heng       4          hunt        wind        30        60
# 2          himeko       5     erudition        fire        30        60
# 3            welt       5      nihility   imaginary        30        30
# 4           kafka       5      nihility   lightning        30        60
# 5     silver_wolf       5      nihility     quantum        30        60
# 6           arlan       4   destruction   lightning        30        60
# 7            asta       4       harmony        fire        30        30
# 8           herta       4     erudition         ice        30        30
# 9          bronya       5       harmony        wind        30         0
# 10          seele       5          hunt     quantum        30        60
# 11         serval       4     erudition   lightning        30        60
# ...

# %%
#Ada berapa jenis rarity character
#Ada berapa jumlah path character di game hsr, ini agar membantu new player mengetahui ada path apa saja, karena setiap path memiliki gameplay yang berbeda
#Ada berapa combat type di hsr
#Tentu dari setiap data tersebut bisa dibuat chart, chart apapun, terlebih pie chart, agar bisa melihat stats setiap data

#Perbandingan, bisa melakukan perbandingan dari data-data tersebut, misalnya jika base attack charakter ditambah 20 mana yang paling tinggi(atk_20), agar kita bisa mengetahui charakter mana yg paling bagus atau op
#Karena di setiap charakter memiliki stat yang berbeda beda, jadi jika attack ditambah maka akan menghasilkan stat damage yang berbeda
#Perbandingan ini bisa dilakukan dengan kolo lainnya, contohnya seperti di kolom hp_20a,def_20 dan lainnya

#Bisa menhitung rata-rata attack/def/hp berdasarkan rarirty atau combat type charakter
#bisa menganalisis optimalisasi strategi dalam game, misalnya memilih karakter terbaik berdasarkan atribut mereka.

#Bisa menganalisis charakter mana yang paling kuat di setiap path
#Bisa menganalisis charakter mana yang paling lemah di setiap path
#Bisa juga menganilisis charakter mana yang paling lemah dan kuat berdasarkan combat type setiap character
#Dengan cara membandingkan setiap stats yang berbeda yang tertera/tersedia di data

#Menghitung rata-rata wb (weakness break) keseluruhan(wb_b-atk,wb_skill, dll) di semua charakter maupun di setiap charcter character dengan path atau combat_type yang berbeda
#tidak hanya wb, tapi stats lainnya bisa

#Bisa menghitung berapa lama max energy diisi berdasarkan er(energy regenation) setiap charackter.

#Bisa melihat, apakah rarity charakter berpengaruh kepada performa charackter
#Dengan mneganalisa setiap data/columb berdasarkan rarity charakter
